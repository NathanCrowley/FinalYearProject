# %%
pip install DrawVennDiagram==0.4.0
# Out:
# Collecting DrawVennDiagram==0.4.0
#   Downloading DrawVennDiagram-0.4.0-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: matplotlib in /home/nathan/.local/lib/python3.8/site-packages (from DrawVennDiagram==0.4.0) (3.4.3)
# Requirement already satisfied: matplotlib-venn in /home/nathan/.local/lib/python3.8/site-packages (from DrawVennDiagram==0.4.0) (0.11.6)
# Requirement already satisfied: cycler>=0.10 in /home/nathan/.local/lib/python3.8/site-packages (from matplotlib->DrawVennDiagram==0.4.0) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib->DrawVennDiagram==0.4.0) (2.7.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->DrawVennDiagram==0.4.0) (7.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/nathan/.local/lib/python3.8/site-packages (from matplotlib->DrawVennDiagram==0.4.0) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nathan/.local/lib/python3.8/site-packages (from matplotlib->DrawVennDiagram==0.4.0) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in /home/nathan/.local/lib/python3.8/site-packages (from matplotlib->DrawVennDiagram==0.4.0) (1.21.2)
# Requirement already satisfied: scipy in /home/nathan/.local/lib/python3.8/site-packages (from matplotlib-venn->DrawVennDiagram==0.4.0) (1.7.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib->DrawVennDiagram==0.4.0) (1.14.0)
# Installing collected packages: DrawVennDiagram
#   Attempting uninstall: DrawVennDiagram
#     Found existing installation: DrawVennDiagram 0.3.0
#     Uninstalling DrawVennDiagram-0.3.0:
#       Successfully uninstalled DrawVennDiagram-0.3.0
# Successfully installed DrawVennDiagram-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from DrawVennDiagram import *

# %%
# State input file
file = "test_model.ivenn"

# Read in data using API's in-built "read_data(file)"
data = read_data(file)

# Set input data to variables
labels = data[0]
mapped_values = data[1]
values = data[2]

print("Labels:",labels,"\n")
print("Origninal Values:",values,"\n")
print("Mapped Values:",mapped_values,"\n")
# Out:
# Labels: ['name1', 'nAme 2', 'Na_Me3', 'Na_Me4', 'Na_Me', 'Na_Me']
#
# Origninal Values: [['e1', 'w2', 'f3', 'e', '3', '4'], ['e122', 'w23', 'f3', 'e', '3', '4', '5', '6', '7', 'g', 'r', 't', 'y', 'd'], ['e1', 'w2', 'f3', 'e', '3', '4', 'w', 'q', 'a', 's', 'd', 'f', 'g', 'h', 'r', 't'], ['4', 'w', 'q', 'a', 's', 'd', 'f', 'g', 'h', 'r', 't', 'm', 'b', 'v', '65', '34', '23'], ['44', 'w4', 'q4', 'a4', 's4', 'd4', 'f4', 'g4', 'h4', 'r4', 't4', 'g', 'm', 'b', 'v', '653', '343', '23'], ['43', 'w3', 'q3', 'a3', 's3', 'd3', 'f3', 'g3', 'h3', 'r3', 't3', 'g', 'm3', 'b3', 'v', '65', '34', '23']]
#
# Mapped Values: [[22, 49, 25, 21, 2, 5], [23, 50, 25, 21, 2, 5, 8, 9, 12, 27, 38, 44, 53, 18], [22, 49, 25, 21, 2, 5, 48, 35, 13, 41, 18, 24, 27, 30, 38, 44]]

# %%
#Step 1: Create Python set objects with mapped values as inputs.
set1 = set(mapped_values[0])
set2 = set(mapped_values[1])

#Step 2: Create a Sets tuple, which contains the Python set objects created in **Step 1**.
sets = (set1,set2)

#Step 3: State the labels you wish to display.
l2 = labels[0:2]

#Step 4: Create a "drawVenn" object, giving the sets tuple from **Step2** and labels from **Step3** as input parameters.
v = drawVenn(sets,l2)

# %%
set1 = set(mapped_values[0])
set2 = set(mapped_values[1])

sets = (set1,set2)
l2 = labels[0:2]

drawVenn(sets,l2)
v.set_dashed_circles()

# %%
#Step 1: Create Python set objects with mapped values as inputs.
set1 = set(mapped_values[0])
set2 = set(mapped_values[1])
set3 = set(mapped_values[2])

#Step 2: Create a Sets tuple, which contains the Python set objects created in **Step 1**.
sets = (set1,set2,set3)

#Step 3: State the labels you wish to display.
l3 = labels[0:3]

#Step 4: Create a "drawVenn" object, giving the sets tuple from **Step2** and labels from **Step3** as input parameters.
v2 = drawVenn(sets,l3,True)

# %%
#Step 1: Create Python set objects with mapped values as inputs.
set1 = set(mapped_values[0])
set2 = set(mapped_values[1])
set3 = set(mapped_values[2])

#Step 2: Create a Sets tuple, which contains the Python set objects created in **Step 1**.
sets = (set1,set2,set3)

#Step 3: State the labels you wish to display.
l3 = labels[0:3]

#Step 4: Create a "drawVenn" object, giving the sets tuple from **Step2** and labels from **Step3** as input parameters.
v3d = drawVenn(sets,l3,True)
v3d.set_dashed_circles()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-65cd8899bd82> in <module>
#      12 #Step 4: Create a "drawVenn" object, giving the sets tuple from **Step2** and labels from **Step3** as input parameters.
#      13 v3d = drawVenn(sets,l3,True)
# ---> 14 v3d.set_dashed_circles()
#
# ~/.local/lib/python3.8/site-packages/DrawVennDiagram/__init__.py in set_dashed_circles(self)
#      62             venn3_circles(self.subsets)
#      63         elif self.number_of_sets == 2: # 2 set Venn diagram
# ---> 64             venn2_circles(self.subsets)
#      65
#      66     def set_dashed_circles(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib_venn/_venn2.py in venn2_circles(subsets, normalize_to, alpha, color, linestyle, linewidth, ax, **kwargs)
#     167     elif len(subsets) == 2:
#     168         subsets = compute_venn2_subsets(*subsets)
# --> 169     areas = compute_venn2_areas(subsets, normalize_to)
#     170     centers, radii = solve_venn2_circles(areas)
#     171
#
# ~/.local/lib/python3.8/site-packages/matplotlib_venn/_venn2.py in compute_venn2_areas(diagram_areas, normalize_to)
#      45     '''
#      46     # Normalize input values to sum to 1
# ---> 47     areas = np.array(np.abs(diagram_areas), float)
#      48     total_area = np.sum(areas)
#      49     if np.abs(total_area) < tol:
#
# TypeError: bad operand type for abs(): 'set'
